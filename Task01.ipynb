# %% [markdown]
# # Task one
# Create a bar char or histogram to visualize the distribution of categorical or continuous variables

# %% [markdown]
# # Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %% [markdown]
# # Data

# %%
data = pd.read_csv("world_pop.csv")

# %%
data
# Out:
#                     Country Name Indicator Code         1960         1961  \
# 0                          Aruba    SP.POP.TOTL      54208.0      55434.0
# 1    Africa Eastern and Southern    SP.POP.TOTL  130836765.0  134159786.0
# 2                    Afghanistan    SP.POP.TOTL    8996967.0    9169406.0
# 3     Africa Western and Central    SP.POP.TOTL   96396419.0   98407221.0
# 4                         Angola    SP.POP.TOTL    5454938.0    5531451.0
# ..                           ...            ...          ...          ...
# 261                       Kosovo    SP.POP.TOTL     947000.0     966000.0
# 262                  Yemen, Rep.    SP.POP.TOTL    5315351.0    5393034.0
# 263                 South Africa    SP.POP.TOTL   17099836.0   17524533.0
# 264                       Zambia    SP.POP.TOTL    3070780.0    3164330.0
# 265                     Zimbabwe    SP.POP.TOTL    3776679.0    3905038.0
#
#             1962         1963         1964         1965         1966  \
# ...

# %%
data.shape
# Out:
# (266, 64)

# %% [markdown]
# As we can see, our dataset contains 226 rows and 66 columns.

# %%
data.head()
# Out:
#                   Country Name Indicator Code         1960         1961  \
# 0                        Aruba    SP.POP.TOTL      54208.0      55434.0
# 1  Africa Eastern and Southern    SP.POP.TOTL  130836765.0  134159786.0
# 2                  Afghanistan    SP.POP.TOTL    8996967.0    9169406.0
# 3   Africa Western and Central    SP.POP.TOTL   96396419.0   98407221.0
# 4                       Angola    SP.POP.TOTL    5454938.0    5531451.0
#
#           1962         1963         1964         1965         1966  \
# 0      56234.0      56699.0      57029.0      57357.0      57702.0
# 1  137614644.0  141202036.0  144920186.0  148769974.0  152752671.0
# 2    9351442.0    9543200.0    9744772.0    9956318.0   10174840.0
# 3  100506960.0  102691339.0  104953470.0  107289875.0  109701811.0
# 4    5608499.0    5679409.0    5734995.0    5770573.0    5781305.0
#
#           1967  ...         2012         2013         2014         2015  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 64 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Indicator Code  266 non-null    object
#  2   1960            264 non-null    float64
#  3   1961            264 non-null    float64
#  4   1962            264 non-null    float64
#  5   1963            264 non-null    float64
#  6   1964            264 non-null    float64
#  7   1965            264 non-null    float64
#  8   1966            264 non-null    float64
#  9   1967            264 non-null    float64
#  10  1968            264 non-null    float64
#  11  1969            264 non-null    float64
#  12  1970            264 non-null    float64
#  13  1971            264 non-null    float64
#  14  1972            264 non-null    float64
#  15  1973            264 non-null    float64
#  16  1974            264 non-null    float64
# ...

# %%
data.columns
# Out:
# Index(['Country Name', 'Indicator Code', '1960', '1961', '1962', '1963',
#        '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972',
#        '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990',
#        '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021'],
#       dtype='object')

# %% [markdown]
# # Missing data

# %%
print(data.isna().sum())
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              2
#                  ..
# 2017              2
# 2018              2
# 2019              2
# 2020              2
# 2021              2
# Length: 66, dtype: int64

# %% [markdown]
#  We can say there is no missing values in our data

# %%
print("Number of duplicates in dataset = ", data.duplicated().sum())
# Out:
# Number of duplicates in dataset =  0

# %%
data.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.170778e+08  1.186224e+08  1.207295e+08  1.233477e+08  1.259870e+08
# std    3.695330e+08  3.738752e+08  3.803881e+08  3.888702e+08  3.973957e+08
# min    2.833000e+03  3.077000e+03  3.367000e+03  3.703000e+03  4.063000e+03
# 25%    5.022802e+05  5.109642e+05  5.206540e+05  5.311622e+05  5.421252e+05
# 50%    3.718330e+06  3.826398e+06  3.929109e+06  4.015834e+06  4.124521e+06
# 75%    2.636053e+07  2.721235e+07  2.808607e+07  2.890669e+07  2.972333e+07
# max    3.032156e+09  3.071596e+09  3.124561e+09  3.189656e+09  3.255146e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.286917e+08  1.315389e+08  1.343785e+08  1.372873e+08  1.403007e+08
# ...

# %%
data.nunique()
# Out:
# Country Name      266
# Country Code      266
# Indicator Name      1
# Indicator Code      1
# 1960              260
#                  ...
# 2017              262
# 2018              262
# 2019              262
# 2020              262
# 2021              262
# Length: 66, dtype: int64

# %%
data.sample()
# Out:
#                                   Country Name Indicator Code         1960  \
# 241  Sub-Saharan Africa (IDA & IBRD countries)    SP.POP.TOTL  227233184.0
#
#             1961         1962         1963         1964         1965  \
# 241  232567007.0  238121604.0  243893375.0  249873656.0  256059849.0
#
#             1966         1967  ...         2012         2013         2014  \
# 241  262454482.0  269072404.0  ...  917725880.0  943039474.0  968958352.0
#
#             2015          2016          2017          2018          2019  \
# 241  995458498.0  1.022530e+09  1.050163e+09  1.078320e+09  1.106958e+09
#
#              2020          2021
# 241  1.136047e+09  1.165564e+09
#
# [1 rows x 64 columns]

# %%
# filter data for total population
total_population_data=data[data['Indicator Code']=='SP.POP.TOTL']
total_population_data
# Out:
#                     Country Name Indicator Code         1960         1961  \
# 0                          Aruba    SP.POP.TOTL      54208.0      55434.0
# 1    Africa Eastern and Southern    SP.POP.TOTL  130836765.0  134159786.0
# 2                    Afghanistan    SP.POP.TOTL    8996967.0    9169406.0
# 3     Africa Western and Central    SP.POP.TOTL   96396419.0   98407221.0
# 4                         Angola    SP.POP.TOTL    5454938.0    5531451.0
# ..                           ...            ...          ...          ...
# 261                       Kosovo    SP.POP.TOTL     947000.0     966000.0
# 262                  Yemen, Rep.    SP.POP.TOTL    5315351.0    5393034.0
# 263                 South Africa    SP.POP.TOTL   17099836.0   17524533.0
# 264                       Zambia    SP.POP.TOTL    3070780.0    3164330.0
# 265                     Zimbabwe    SP.POP.TOTL    3776679.0    3905038.0
#
#             1962         1963         1964         1965         1966  \
# ...

# %%
# sort data based on total population for 2021
total_population_sort = total_population_data.sort_values(by='2021',ascending=False)
total_population_sort
# Out:
#             Country Name Indicator Code          1960          1961  \
# 259                World    SP.POP.TOTL  3.032156e+09  3.071596e+09
# 103     IDA & IBRD total    SP.POP.TOTL  2.299245e+09  2.329155e+09
# 140  Low & middle income    SP.POP.TOTL  2.244700e+09  2.273945e+09
# 156        Middle income    SP.POP.TOTL  2.103847e+09  2.129932e+09
# 102            IBRD only    SP.POP.TOTL  1.919643e+09  1.940357e+09
# ..                   ...            ...           ...           ...
# 188                Palau    SP.POP.TOTL  9.769000e+03  1.004600e+04
# 245               Tuvalu    SP.POP.TOTL  5.321000e+03  5.330000e+03
# 179                Nauru    SP.POP.TOTL  4.377000e+03  4.627000e+03
# 69               Eritrea    SP.POP.TOTL  1.007586e+06  1.033320e+06
# 110       Not classified    SP.POP.TOTL           NaN           NaN
#
#              1962          1963          1964          1965          1966  \
# 259  3.124561e+09  3.189656e+09  3.255146e+09  3.322047e+09  3.392098e+09
# ...

# %% [markdown]
# get top 10 countries with the highest population for 2021

# %%
# get top 10 countries with the highest population for 2021
top_ten_countries = total_population_sort.head()
print("Top Ten Counteies Of Total Population:-")
print(top_ten_countries)
# Out:
# Top Ten Counteies Of Total Population:-
#             Country Name Indicator Code          1960          1961  \
# 259                World    SP.POP.TOTL  3.032156e+09  3.071596e+09
# 103     IDA & IBRD total    SP.POP.TOTL  2.299245e+09  2.329155e+09
# 140  Low & middle income    SP.POP.TOTL  2.244700e+09  2.273945e+09
# 156        Middle income    SP.POP.TOTL  2.103847e+09  2.129932e+09
# 102            IBRD only    SP.POP.TOTL  1.919643e+09  1.940357e+09
#
#              1962          1963          1964          1965          1966  \
# 259  3.124561e+09  3.189656e+09  3.255146e+09  3.322047e+09  3.392098e+09
# 103  2.372381e+09  2.427869e+09  2.483840e+09  2.541415e+09  2.602627e+09
# 140  2.316484e+09  2.371218e+09  2.426432e+09  2.483423e+09  2.544090e+09
# 156  2.169233e+09  2.220611e+09  2.272301e+09  2.325560e+09  2.382277e+09
# 102  1.974019e+09  2.019554e+09  2.065153e+09  2.111931e+09  2.161881e+09
#
#              1967  ...          2012          2013          2014  \
# ...

# %% [markdown]
# # Data visualization

# %%
# Data visualization
def add_value_labels(ax,spacing=10):
    for rect in ax.patches:
        x=rect.get_x()+rect.get_width()/2
        y=rect.get_height()-3
        
        va='bottom' if y>=0 else 'top'
        label= '()'.format(y) 
        y_shift = spacing * (1 if y >= 0 else -1)
        ax.annotate(label,(x,y),xytext=(0,y_shift),textcoords="offset points",ha='center',va=va)

# %% [markdown]
# # Top ten counteirs of total population in year 2022 and 2000

# %%
# creat a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='2021',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population (2022)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2000',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population in 2000")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# # Top ten counteirs of total population in year 1999 and 1989

# %%
# creat a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1999',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population (1999)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1989',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population in 1989")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# # Top ten counteirs of total population in year 1960 and 2021

# %%
# creat a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1960',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population (1999)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2021',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population in 1989")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# # get bottom 10 countries with the highest population

# %%
# sort data based on total population for 2022
total_population_sort_bt = total_population_data.sort_values(by='2021',ascending=True)
total_population_sort_bt
# Out:
#                Country Name Indicator Code          1960          1961  \
# 179                   Nauru    SP.POP.TOTL  4.377000e+03  4.627000e+03
# 245                  Tuvalu    SP.POP.TOTL  5.321000e+03  5.330000e+03
# 188                   Palau    SP.POP.TOTL  9.769000e+03  1.004600e+04
# 255  British Virgin Islands    SP.POP.TOTL  8.053000e+03  8.164000e+03
# 84                Gibraltar    SP.POP.TOTL  2.342000e+04  2.380800e+04
# ..                      ...            ...           ...           ...
# 140     Low & middle income    SP.POP.TOTL  2.244700e+09  2.273945e+09
# 103        IDA & IBRD total    SP.POP.TOTL  2.299245e+09  2.329155e+09
# 259                   World    SP.POP.TOTL  3.032156e+09  3.071596e+09
# 69                  Eritrea    SP.POP.TOTL  1.007586e+06  1.033320e+06
# 110          Not classified    SP.POP.TOTL           NaN           NaN
#
#              1962          1963          1964          1965          1966  \
# ...

# %%
top_ten_bt_countries = total_population_sort_bt.head(10)
print("Top Ten Bottom Counteies Of Total Population:-")
print(top_ten_bt_countries)
# Out:
# Top Ten Bottom Counteies Of Total Population:-
#                  Country Name Indicator Code     1960     1961     1962  \
# 179                     Nauru    SP.POP.TOTL   4377.0   4627.0   4942.0
# 245                    Tuvalu    SP.POP.TOTL   5321.0   5330.0   5340.0
# 188                     Palau    SP.POP.TOTL   9769.0  10046.0  10329.0
# 255    British Virgin Islands    SP.POP.TOTL   8053.0   8164.0   8319.0
# 84                  Gibraltar    SP.POP.TOTL  23420.0  23808.0  24307.0
# 212                San Marino    SP.POP.TOTL  15440.0  15836.0  16255.0
# 137             Liechtenstein    SP.POP.TOTL  16501.0  16894.0  17300.0
# 228  Turks and Caicos Islands    SP.POP.TOTL   5825.0   5867.0   5884.0
# 147  St. Martin (French part)    SP.POP.TOTL   3898.0   3996.0   4078.0
# 149                    Monaco    SP.POP.TOTL  22461.0  22813.0  23043.0
#
#         1963     1964     1965     1966     1967  ...     2012     2013  \
# ...

# %% [markdown]
# # Bottom ten counteirs of total population in year 2021 and 2000

# %%
# creat a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='2021',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population (2022)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2000',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population in 2000")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# # Bottom ten counteirs of total population in year 1999 and 1989

# %%
# creat a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1999',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population (1999)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1989',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population in 1989")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# # Bottom ten counteirs of total population in year 1960 and 2021

# %%
# creat a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1960',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population (1960)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2021',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population in 2022")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
